# %% [markdown]
# # Inicio geoinformatica
#
# Notebook base para probar el entorno `Python (geo)` y correr un flujo raster/vector simple.

# %%
from pathlib import Path
import runpy

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
PROJECT_ROOT

# %% [markdown]
# ## 1. Chequear entorno

# %%
runpy.run_path(str(PROJECT_ROOT / 'scripts' / '00_check_setup.py'), run_name='__main__')

# %% [markdown]
# ## 2. Crear datos ficticios

# %%
runpy.run_path(str(PROJECT_ROOT / 'scripts' / '01_create_sample_data.py'), run_name='__main__')

# %% [markdown]
# ## 3. Calcular NDWI y estadisticas zonales

# %%
runpy.run_path(str(PROJECT_ROOT / 'scripts' / '02_ndwi_zonal_stats.py'), run_name='__main__')

# %% [markdown]
# ## 4. Ver tabla de resultados

# %%
import pandas as pd

pd.read_csv(PROJECT_ROOT / 'outputs' / 'zonas_ndwi_stats.csv')

# %% [markdown]
# ## 5. Crear mapas

# %%
runpy.run_path(str(PROJECT_ROOT / 'scripts' / '03_visualize_results.py'), run_name='__main__')

# %% [markdown]
# ## 6. Abrir mapa interactivo
#
# El HTML queda en `outputs/mapa_interactivo.html`.
